# %%
import os
os.environ['GMINI_API_KEY']= "AIzaSyC1-KxZ89Jdt741SCrvkI79Ut8n5jEv7IE"

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GMINI_API_KEY'])

# %%
model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")
response = model.generate_content("Job opportunity what would future scope of AI in 2030")
print(response.text)
# Out:
# Okay, let's break down the future scope of AI job opportunities specifically looking towards 2030.
#
# The short answer is: **The future scope of AI jobs in 2030 is highly promising, characterized by significant growth, transformation, and the creation of entirely new roles, alongside the need for adaptation and reskilling in existing professions.**
#
# Here's a more detailed look at what that means for job opportunities:
#
# **1. Massive Growth in Core AI Roles:**
#
# *   **AI Researchers & Scientists:** The demand for individuals pushing the boundaries of AI algorithms, machine learning models, and neural networks will continue to surge. This includes specializing in areas like deep learning, reinforcement learning, natural language processing (NLP), computer vision, etc.
# *   **Machine Learning Engineers (MLEs):** These are the engineers who build, deploy, and maintain ML models in production. The need for MLEs will explode as more companies move from AI experimentation to large-scale implementation. This includes MLOps (ML Operations) specialists focused on automation, monitoring, and scaling AI systems.
# *   **Data Scientists & Analysts:** AI is fueled by data. The roles focused on collecting, cleaning, analyzing, interpreting data, and preparing it for AI models will remain critically important. Data engineering (building the data pipelines) will also be in high demand.
# *   **AI Architects & System Designers:** As AI systems become more complex and integrated, there will be a greater need for architects who can design robust, scalable, and ethical AI solutions across different platforms and domains.
#
# **2. Emergence of New, AI-Specific Roles:**
#
# *   **Prompt Engineers / AI Interaction Designers:** With the rise of large language models (like GPT), roles focused on crafting effective prompts, training, and fine-tuning these models for specific tasks will become common. This is about understanding how to get the best output from AI.
# *   **AI Ethicists & Governance Specialists:** As AI becomes more powerful and integrated into society, the need for professionals who understand the ethical implications, potential biases, regulatory frameworks, and responsible deployment of AI will be crucial.
# *   **AI Trainers & Explainers:** Roles focused on training AI models (e.g., data labeling, model validation) and, importantly, explaining complex AI decisions to non-experts will grow. Explainable AI (XAI) is a key area.
# *   **AI Integration Specialists:** Professionals skilled in integrating AI solutions into existing business processes, software, and hardware.
#
# **3. Transformation and Augmentation of Existing Jobs:**
#
# *   **AI will be a powerful tool:** Many existing roles across almost *every* industry will be augmented by AI. Professionals in healthcare, finance, marketing, law, education, manufacturing, customer service, etc., will need to learn how to effectively use AI tools to perform their jobs better and more efficiently.
# *   **Focus shifts to higher-level tasks:** As AI automates routine or repetitive tasks, human workers can focus on more complex problem-solving, creative thinking, strategic planning, and tasks requiring empathy and interpersonal skills.
# *   **Demand for Human-AI Collaboration Skills:** Being able to effectively collaborate *with* AI systems will be a core competency for many roles.
#
# **4. Skills in High Demand for 2030:**
#
# Beyond core technical skills (programming languages like Python, ML frameworks like TensorFlow/PyTorch, cloud platforms), crucial skills will include:
#
# *   **Deep Understanding of ML/AI Concepts:** Not just using tools, but understanding *how* they work.
# *   **Data Literacy:** Ability to work with, understand, and interpret data.
# *   **AI-Specific Skills:** Prompt engineering, MLOps, Explainable AI.
# *   **Critical Thinking & Problem Solving:** Applying AI to solve real-world issues.
# *   **Adaptability & Continuous Learning:** AI is rapidly evolving, requiring constant skill updates.
# *   **Creativity & Innovation:** Applying AI in novel ways.
# *   **Ethical Reasoning & Responsibility:** Understanding the societal impact of AI.
# *   **Communication & Collaboration:** Working effectively with both technical and non-technical teams, and increasingly, with AI itself.
#
# **5. Job Displacement & The Need for Reskilling:**
#
# While there's massive job creation, it's also important to acknowledge that certain jobs, particularly those highly routine and repetitive, may be automated away or significantly reduced. This highlights the critical need for:
#
# *   **Reskilling and Upskilling Initiatives:** Education and training programs will be essential to help the workforce transition into AI-centric or AI-augmented roles.
# *   **Focus on Human-Centric Skills:** Roles requiring high emotional intelligence, complex social interaction, nuanced judgment, and pure creativity are less likely to be automated by 2030.
#
# **Conclusion:**
#
# By 2030, AI will not just be a niche tech field; it will be a fundamental part of the global economy and workforce. The scope for job opportunities is immense, spanning from core research and engineering to deployment, integration, ethics, and the augmentation of almost every existing profession.
#
# For individuals looking at career paths, specializing in AI (either building, deploying, or responsibly managing it) or developing strong skills in how to effectively use AI tools within their chosen field will offer significant career advantages and opportunities. The future is less about humans *vs.* AI, and more about humans working *with* AI.

# %%
import pathlib
import textwrap

import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    """Display text as markdown."""
    text = text.replace('*', '  *')
    return Markdown(textwrap.indent(text, ' >', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it

# %%
# model = genai.GenerativeModel("gemini-2.5-pro-exp-03-25")
model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")

# %%
# %%time
response= model.generate_content("create a table for summarize to a kid about datascince vs machine learning vs nlp vs deep learning vs neural network vs generative AI vs agentic ai vs mcp vs agi and save this generated file to my computer as a pdf file")
# Out:
# CPU times: total: 62.5 ms
# Wall time: 19.4 s

# %%
to_markdown(response.text)  # finetune
# Out:
#  >Okay, I can definitely help you summarize these cool tech ideas for a kid! We'll put it into a simple table.
#  >
#  >However, I   *  *cannot  *  * directly save a file (like a PDF) onto your computer. That's something only you can do from your web browser or operating system for security reasons.
#  >
#  >What I   *can  * do is create the table here for you. You can then easily   *  *copy and paste  *  * it into a document program (like Microsoft Word, Google Docs, or even a simple text editor) and then use that program's "Save As PDF" or "Print to PDF" function.
#  >
#  >Here is the table explaining these concepts simply for a kid:
#  >
#  >---
#  >
#  >  *  *Cool Computer Brain Stuff: Explained Simply!  *  *
#  >
#  >Think of computers being really, really smart helpers! Here are some ways they get smart and what they can do:
#  >
#  >| What is it?                                 | Imagine it's like...                                    | What does it do?                                                                 | Is it part of something bigger?                     |
#  >| :------------------------------------------ | :------------------------------------------------------ | :------------------------------------------------------------------------------- | :-------------------------------------------------- |
#  >|   *  *Data Science  *  *                            | A detective looking at lots of clues (data)!          | Looks at tons of information to find secrets and patterns.                       | Uses ML, DL, etc.                                   |
#  >|   *  *Machine Learning (ML)  *  *                   | Teaching a computer tricks by showing it examples.        | Helps computers learn from data without being told   *exactly  * what to do every time. | Part of Data Science.                               |
#  >|   *  *Natural Language Processing (NLP)  *  *       | A computer that understands talking and writing.        | Helps computers read, understand, and talk like humans (like Siri or Alexa).     | Often uses ML and DL.                               |
#  >|   *  *Deep Learning (DL)  *  *                      | Stacking many layers of learning blocks super high.       | A special way computers learn really complex things very well (like seeing faces). | A   *type  * of Machine Learning. Uses Neural Networks. |
#  >|   *  *Neural Network (NN)  *  *                     | Tiny connected learning bits, like cells in your brain. | The basic parts that Deep Learning uses to learn and find patterns.              | What Deep Learning is built from.                   |
#  >|   *  *Generative AI  *  *                           | A magic creator!                                        | Makes brand new things like pictures, stories, music, or even videos.            | Often uses DL and NNs.                              |
#  >|   *  *Agentic AI  *  *                              | A helpful robot helper that   *acts  * on its own!          | Can make decisions and   *do  * tasks by itself to finish something you ask it to.   | Uses ML, DL, NLP, etc.                              |
#  >|   *  *MCP  *  *                                     |   *(This isn't a standard term like the others here.)  *   |   *(This isn't a standard term like the others here.)  *                              |   *(Unclear in this context.)  *                         |
#  >|   *  *AGI (Artificial General Intelligence)  *  * | A computer brain as smart as a human at   *everything  *!   | A future goal: a super-smart AI that can learn and do anything a human can.      | (Not here yet! Would probably use all the others).  |
#  >
#  >---
#  >
#  >  *  *How to get this as a PDF:  *  *
#  >
#  >1.    *  *Copy the Text:  *  * Select all the text above (from "Cool Computer Brain Stuff" down to the end of the table).
#  >2.    *  *Open a Document Program:  *  * Open something like Microsoft Word, Google Docs, Apple Pages, or even a free online text editor.
#  >3.    *  *Paste:  *  * Paste the copied text into the new document.
#  >4.    *  *Save/Export as PDF:  *  *
#  >      *   In most programs, go to `File` -> `Save As`. Choose a location on your computer and select `PDF` as the file type.
#  >      *   Alternatively, go to `File` -> `Print`. In the print dialog, instead of choosing a printer, look for an option like "Save as PDF" or "Print to PDF".
#  >
#  >This way, you can save the information on your own computer as a PDF file!
#  >
#  >  *(Note: I've included MCP but added a note that it's not a standard term in this context, as it's important for the table to be clear and accurate for a kid.)  *

# %%
for chunk in response:
    print(chunk.text)
     # chunk is a string token is andividual token
# Out:
# Okay, I can definitely help you summarize these cool tech ideas for a kid! We'll put it into a simple table.
#
# However, I **cannot** directly save a file (like a PDF) onto your computer. That's something only you can do from your web browser or operating system for security reasons.
#
# What I *can* do is create the table here for you. You can then easily **copy and paste** it into a document program (like Microsoft Word, Google Docs, or even a simple text editor) and then use that program's "Save As PDF" or "Print to PDF" function.
#
# Here is the table explaining these concepts simply for a kid:
#
# ---
#
# **Cool Computer Brain Stuff: Explained Simply!**
#
# Think of computers being really, really smart helpers! Here are some ways they get smart and what they can do:
#
# | What is it?                                 | Imagine it's like...                                    | What does it do?                                                                 | Is it part of something bigger?                     |
# | :------------------------------------------ | :------------------------------------------------------ | :------------------------------------------------------------------------------- | :-------------------------------------------------- |
# | **Data Science**                            | A detective looking at lots of clues (data)!          | Looks at tons of information to find secrets and patterns.                       | Uses ML, DL, etc.                                   |
# | **Machine Learning (ML)**                   | Teaching a computer tricks by showing it examples.        | Helps computers learn from data without being told *exactly* what to do every time. | Part of Data Science.                               |
# | **Natural Language Processing (NLP)**       | A computer that understands talking and writing.        | Helps computers read, understand, and talk like humans (like Siri or Alexa).     | Often uses ML and DL.                               |
# | **Deep Learning (DL)**                      | Stacking many layers of learning blocks super high.       | A special way computers learn really complex things very well (like seeing faces). | A *type* of Machine Learning. Uses Neural Networks. |
# | **Neural Network (NN)**                     | Tiny connected learning bits, like cells in your brain. | The basic parts that Deep Learning uses to learn and find patterns.              | What Deep Learning is built from.                   |
# | **Generative AI**                           | A magic creator!                                        | Makes brand new things like pictures, stories, music, or even videos.            | Often uses DL and NNs.                              |
# | **Agentic AI**                              | A helpful robot helper that *acts* on its own!          | Can make decisions and *do* tasks by itself to finish something you ask it to.   | Uses ML, DL, NLP, etc.                              |
# | **MCP**                                     | *(This isn't a standard term like the others here.)*   | *(This isn't a standard term like the others here.)*                              | *(Unclear in this context.)*                         |
# | **AGI (Artificial General Intelligence)** | A computer brain as smart as a human at *everything*!   | A future goal: a super-smart AI that can learn and do anything a human can.      | (Not here yet! Would probably use all the others).  |
#
# ---
#
# **How to get this as a PDF:**
#
# 1.  **Copy the Text:** Select all the text above (from "Cool Computer Brain Stuff" down to the end of the table).
# 2.  **Open a Document Program:** Open something like Microsoft Word, Google Docs, Apple Pages, or even a free online text editor.
# 3.  **Paste:** Paste the copied text into the new document.
# 4.  **Save/Export as PDF:**
#     *   In most programs, go to `File` -> `Save As`. Choose a location on your computer and select `PDF` as the file type.
#     *   Alternatively, go to `File` -> `Print`. In the print dialog, instead of choosing a printer, look for an option like "Save as PDF" or "Print to PDF".
#
# This way, you can save the information on your own computer as a PDF file!
#
# *(Note: I've included MCP but added a note that it's not a standard term in this context, as it's important for the table to be clear and accurate for a kid.)*

# %%
import PIL.Image
img = PIL.Image.open(r"C:\Users\mohap\Downloads\Screenshot_20210709-110038_2.png")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=672x449>

# %%
model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")

# %%
response = model.generate_content(img)
to_markdown(response.text)  # finetune
# Out:
#  >The image shows a family of four posing for a portrait. On the left is a woman wearing a reddish top and a patterned saree. To her right are two young children, standing in front of a blue background. The child in the front is smaller and wears a yellow top. The child behind him is slightly taller and wears a dark shirt with a light pattern. On the right side of the image is a man wearing a light blue long-sleeved shirt. The background is a solid blue color and there are some decorative elements on the left and right sides of the frame.

# %%
import streamlit as st
import os
from PIL import Image
import textwrap
from IPython.display import Markdown

import google.generativeai as genai

# Configure API key
os.environ['GMINI_API_KEY'] = "AIzaSyC1-KxZ89Jdt741SCrvkI79Ut8n5jEv7IE"
genai.configure(api_key=os.environ['GMINI_API_KEY'])

# Helper function to format text as Markdown
def to_markdown(text):
    """Display text as markdown."""
    text = text.replace('*', '  *')
    return textwrap.indent(text, ' >', predicate=lambda _: True)

# Streamlit app
st.title("Generative AI Content Generator")
st.sidebar.header("Options")

# Model selection
model_name = st.sidebar.selectbox(
    "Select Model",
    [m.name for m in genai.list_models() if 'generateContent' in m.supported_generation_methods]
)
model = genai.GenerativeModel(model_name)

# Input options
input_type = st.sidebar.radio("Input Type", ["Text Prompt", "Image Upload"])

if input_type == "Text Prompt":
    prompt = st.text_area("Enter your prompt:")
    if st.button("Generate Content"):
        with st.spinner("Generating content..."):
            response = model.generate_content(prompt)
            st.markdown(to_markdown(response.text))
elif input_type == "Image Upload":
    uploaded_image = st.file_uploader("Upload an image", type=["jpg", "jpeg", "png"])
    if uploaded_image is not None:
        img = Image.open(uploaded_image)
        st.image(img, caption="Uploaded Image", use_column_width=True)
        if st.button("Generate Content from Image"):
            with st.spinner("Generating content..."):
                response = model.generate_content(img)
                st.markdown(to_markdown(response.text))

# Footer
st.sidebar.info("Powered by Google Generative AI")
# Out:
# 2025-04-24 09:53:02.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:02.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:02.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:02.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 09:53:03.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())
